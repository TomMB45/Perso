# %% [markdown]
# # Première analyse descriptive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import random 
random.seed(42)

# %%
df = pd.read_csv('../data/Fraud.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df = df.sample(n=200_000, random_state=42) # on prend un échantillon de 200 000 lignes pour accélérer le calcul

# %%
df['isFraud'].value_counts()[1]/df.shape[0]
# Out:
# 0.00134

# %% [markdown]
# On observe que 0.13 % des transactions sont frauduleuses dans le dataset.

# %%
sns.countplot(x='isFraud', data=df)
plt.show()
