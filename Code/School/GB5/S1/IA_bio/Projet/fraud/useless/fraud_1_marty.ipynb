# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/Fraud.csv')

# %%
df_fraud = df[df['isFraud'] == 1]
df_fraud.shape
df_fraud.head(30)
# Out:
#       step      type       amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        1  TRANSFER       181.00  C1305486145         181.00            0.00
# 3        1  CASH_OUT       181.00   C840083671         181.00            0.00
# 251      1  TRANSFER      2806.00  C1420196421        2806.00            0.00
# 252      1  CASH_OUT      2806.00  C2101527076        2806.00            0.00
# 680      1  TRANSFER     20128.00   C137533655       20128.00            0.00
# 681      1  CASH_OUT     20128.00  C1118430673       20128.00            0.00
# 724      1  CASH_OUT    416001.33   C749981943           0.00            0.00
# 969      1  TRANSFER   1277212.77  C1334405552     1277212.77            0.00
# 970      1  CASH_OUT   1277212.77   C467632528     1277212.77            0.00
# 1115     1  TRANSFER     35063.63  C1364127192       35063.63            0.00
# 1116     1  CASH_OUT     35063.63  C1635772897       35063.63            0.00
# ...

# %%
df_fraud['nD_count'] = df_fraud.groupby('nameDest')['nameDest'].transform('count')
df_fraud_again = df_fraud[df_fraud['nD_count'] > 1]
df_fraud_again.shape
df_fraud_again

# %%
df_fraud_again['nameDest'].nunique()
#Nombre de comptes receveur ayant été utilisé dans 2 fraudes

# %%
df_fraud['nO_count'] = df_fraud.groupby('nameOrig')['nameOrig'].transform('count')
df_frauded_again = df_fraud[df_fraud['nO_count'] > 1]
df_frauded_again.shape
#Aucun compte n'a été 2 fois victime de fraudedf_frauded_again = df_fraud[df_fraud['nO_count'] > 1]
df_frauded_again.shape
#Aucun compte n'a été victime de fraude plus d'une fois

# %%
df_fraud['new_balance_count'] = df_fraud.groupby('newbalanceOrig')['newbalanceOrig'].transform('count')
df_frauded_sold = df_fraud[df_fraud['new_balance_count'] ==  0 ]
df_frauded_again.shape
#Toutes les Fraudes se traduisent par le fait que le compte soit vidé 
#Checker qu'un virement (qui vide un compte 1 )sur un compte 2 n'est pas cash out après par les compte 2

# %%
df_fraud.head(20)

# %%
cpt_2 = df_fraud['nameDest']                                                                                                                                                        ²
df_cash_out = df.loc[df['nameOrig'].isin(cpt_2)]
df_cash_out.head()
df_cash_out.shape
